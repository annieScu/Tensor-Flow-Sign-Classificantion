# %% [markdown]
# ## 1 - Import packages

# %% [markdown]
# **Exercise**: Please mount your Google drive, and set up your working folder here.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
# start your code here
os.chdir("/content/drive/MyDrive/Homework6") # change your working folder here

# end your code here

# %%
import math
import numpy as np
import h5py
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.python.framework import ops
from tf_utils import load_dataset, random_mini_batches, convert_to_one_hot, predict

# %matplotlib inline
np.random.seed(123)
tf.random.set_seed(123)

# %% [markdown]
# # 2 - Problem statement: SIGNS Dataset
#
# One afternoon, with some friends we decided to teach our computers to decipher sign language. We spent a few hours taking pictures in front of a white wall and came up with the following dataset. It's now your job to build an algorithm that would facilitate communications from a speech-impaired person to someone who doesn't understand sign language.
#
# - **Training set**: 1080 pictures (64 by 64 pixels) of signs representing numbers from 0 to 5 (180 pictures per number).
# - **Test set**: 120 pictures (64 by 64 pixels) of signs representing numbers from 0 to 5 (20 pictures per number).
#
# Note that this is a subset of the SIGNS dataset. The complete dataset contains many more signs.
#
# Here are examples for each number, and how an explanation of how we represent the labels. These are the original pictures, before we lowered the image resolutoion to 64 by 64 pixels.
# <figure>
# <center>
# <img src='https://drive.google.com/uc?id=1Nuox7mBJMGQt_QXZxmYGkXFEO5mjPf-B' />
# <figcaption>Image Caption</figcaption></center>
# </figure>
#
#
# Run the following code to load the dataset.

# %%
# Loading the dataset
X_train_orig, Y_train_orig, X_test_orig, Y_test_orig, classes = load_dataset()

# %% [markdown]
# Change the index below and run the cell to visualize some examples in the dataset.

# %%
# Example of a picture
index = 5
plt.imshow(X_train_orig[index])
print ("y = " + str(np.squeeze(Y_train_orig[:, index])))
# Out:
# y = 4

# %% [markdown]
# # 3. Using One Hot encodings
#
# Many times in deep learning you will have a y vector with numbers ranging from 0 to C-1, where C is the number of classes. If C is for example 4, then you might have the following y vector which you will need to convert as follows:
# <figure>
# <center>
# <img src='https://drive.google.com/uc?id=1P02l9Fu2flQp0gsRl2bTAm0bsZ2cIMWI' />
# <figcaption>
# </figure>
#
#
#
# This is called a "one hot" encoding, because in the converted representation exactly one element of each column is "hot" (meaning set to 1). In tensorflow, we can tranform the labels of samples to one hot vectors by calling
#
# ```
# tf.keras.utils.to_categorical(y)
# ```
# Please transform the lables (or the output of the dataset) to one hot vectors.

# %% [markdown]
# As usual you flatten the image dataset, then normalize it by dividing by 255. On top of that, you will convert each label to a one-hot vector . Run the cell below to do so.

# %%
# Flatten the training and test images
X_train_flatten = X_train_orig.reshape(X_train_orig.shape[0], -1)
X_test_flatten = X_test_orig.reshape(X_test_orig.shape[0], -1)
# Normalize image vectors
X_train = X_train_flatten/255.
X_test = X_test_flatten/255.
# Flatten the training and test labels
Y_train_flatten=Y_train_orig.flatten()
Y_test_flatten=Y_test_orig.flatten()

# Convert training labels (Y_train_flatten) and test labels (Y_test_flatten) to one hot matrices\
### START CODE HERE ###'
Y_train = tf.keras.utils.to_categorical(Y_train_flatten)
Y_test =tf.keras.utils.to_categorical(Y_test_flatten)
### END CODE HERE ###

print ("number of training examples = " + str(X_train.shape[1]))
print ("number of test examples = " + str(X_test.shape[1]))
print ("X_train shape: " + str(X_train.shape))
print ("Y_train shape: " + str(Y_train.shape))
print ("X_test shape: " + str(X_test.shape))
print ("Y_test shape: " + str(Y_test.shape))
# Out:
# number of training examples = 12288
# number of test examples = 12288
# X_train shape: (1080, 12288)
# Y_train shape: (1080, 6)
# X_test shape: (120, 12288)
# Y_test shape: (120, 6)

# %% [markdown]
# **Note** that 12288 comes from $64 \times 64 \times 3$. Each image is square, 64 by 64 pixels, and 3 is for the RGB colors. Please make sure all these shapes make sense to you before continuing.

# %% [markdown]
# #4.Building your model
#
# **Your goal** is to build an model capable of recognizing a sign with high accuracy. To do so, you are going to build a tensorflow model that is almost the same as one you have previously built for cat recognition and multi-class classification problems. If you already forget previous homeworks, please go back to review them to get some clues.
#
# **Previous related homeworks**
#
# "Planar_data_tensorflow.ipynb" in Homework 2
#
# "deepNN_tensorflow.ipynb" in Homework 3
#
# "regularized_deepNN_tensorflow.ipynb" in Homework 4
#
# "batch-size-test-student-version.ipynb" In Homework 5

# %%
### START CODE HERE ###
model=tf.keras.Sequential([
    #Input layer                      
    tf.keras.layers.Input(shape=(12288)), # Set how many elements are there in every training image?

    #Start adding hidden layers  
    tf.keras.layers.Dense(50, activation='relu',
                          kernel_initializer='glorot_uniform',# we will randomly choose the initial weight using the 'glorot_uniform' method as the activation function
                          bias_initializer='zeros', # we will initialize all bias to be zeros.
                          kernel_regularizer=tf.keras.regularizers.L2(0.01)), # Please set your neuron numbers, activation function and so on. 
    
    tf.keras.layers.Dense(40, activation='relu',
                          kernel_initializer='glorot_uniform',# we will randomly choose the initial weight using the 'glorot_uniform' method as the activation function
                          bias_initializer='zeros', # we will initialize all bias to be zeros.
                          kernel_regularizer=tf.keras.regularizers.L2(0.01)),
   tf.keras.layers.Dense(20, activation='relu',
                          kernel_initializer='glorot_uniform',# we will randomly choose the initial weight using the 'glorot_uniform' method as the activation function
                          bias_initializer='zeros', # we will initialize all bias to be zeros.
                          kernel_regularizer=tf.keras.regularizers.L2(0.01)),
    #please feel free to add more hidden layers here. 
     

    # End adding hidden layers 

    #output layer                   
    tf.keras.layers.Dense(6, activation='softmax') # Set how many elements are there in every training output
            
])
### END CODE HERE ###'
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 50)                614450
#
#  dense_1 (Dense)             (None, 40)                2040
#
#  dense_2 (Dense)             (None, 20)                820
#
#  dense_3 (Dense)             (None, 6)                 126
#
# =================================================================
# Total params: 617,436
# Trainable params: 617,436
# Non-trainable params: 0
# _________________________________________________________________

# %%
### START CODE HERE ###'
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.00001),  # Optimizer. Please change 'None' to some meaningful learning rate which is usually <1
              loss= tf.keras.losses.BinaryCrossentropy(), # loss. Please change 'None' to some meaningful loss
              # List of metrics to monitor
              metrics=['accuracy'],
                 )
### END CODE HERE ###'

# %%
### START CODE HERE ###'
history = model.fit(
    X_train , #  training input data
    Y_train, # training output data
   # validation_split=0.1,
    batch_size=7, # how many samples (points) do you want to use to update weights once? 
    epochs=100 # how many iterations do you want to train your model? Your data will be reused to train the model for the number of epochs. I trained 5 min for this model
)
### END CODE HERE ###'
# Out:
# Epoch 1/100
# 155/155 [==============================] - 1s 5ms/step - loss: 0.2078 - accuracy: 0.9898
# Epoch 2/100
# 155/155 [==============================] - 1s 5ms/step - loss: 0.2072 - accuracy: 0.9907
# Epoch 3/100
# 155/155 [==============================] - 1s 5ms/step - loss: 0.2103 - accuracy: 0.9852
# Epoch 4/100
# 155/155 [==============================] - 1s 5ms/step - loss: 0.2076 - accuracy: 0.9907
# Epoch 5/100
# 155/155 [==============================] - 1s 5ms/step - loss: 0.2082 - accuracy: 0.9917
# Epoch 6/100
# 155/155 [==============================] - 1s 5ms/step - loss: 0.2083 - accuracy: 0.9870
# Epoch 7/100
# 155/155 [==============================] - 1s 5ms/step - loss: 0.2069 - accuracy: 0.9889
# Epoch 8/100
# 155/155 [==============================] - 1s 5ms/step - loss: 0.2060 - accuracy: 0.9917
# Epoch 9/100
# 155/155 [==============================] - 1s 5ms/step - loss: 0.2063 - accuracy: 0.9907
# Epoch 10/100
# 155/155 [==============================] - 1s 5ms/step - loss: 0.2071 - accuracy: 0.9898
# Epoch 11/100
# 155/155 [==============================] - 1s 5ms/step - loss: 0.2068 - accuracy: 0.9917
# Epoch 12/100
# 155/155 [==============================] - 1s 5ms/step - loss: 0.2072 - accuracy: 0.9935
# Epoch 13/100
# 155/155 [==============================] - 1s 5ms/step - loss: 0.2066 - accuracy: 0.9926
# Epoch 14/100
# 155/155 [==============================] - 1s 5ms/step - loss: 0.2067 - accuracy: 0.9880
# Epoch 15/100
# 155/155 [==============================] - 1s 5ms/step - loss: 0.2080 - accuracy: 0.9898
# Epoch 16/100
# 155/155 [==============================] - 1s 5ms/step - loss: 0.2070 - accuracy: 0.9861
# Epoch 17/100
# 155/155 [==============================] - 1s 5ms/step - loss: 0.2090 - accuracy: 0.9870
# Epoch 18/100
# 155/155 [==============================] - 1s 5ms/step - loss: 0.2067 - accuracy: 0.9880
# Epoch 19/100
# 155/155 [==============================] - 1s 4ms/step - loss: 0.2075 - accuracy: 0.9917
# Epoch 20/100
# 155/155 [==============================] - 1s 5ms/step - loss: 0.2096 - accuracy: 0.9870
# Epoch 21/100
# 155/155 [==============================] - 1s 4ms/step - loss: 0.2056 - accuracy: 0.9926
# Epoch 22/100
# 155/155 [==============================] - 1s 5ms/step - loss: 0.2096 - accuracy: 0.9889
# Epoch 23/100
# 155/155 [==============================] - 1s 5ms/step - loss: 0.2077 - accuracy: 0.9889
# Epoch 24/100
# 155/155 [==============================] - 1s 4ms/step - loss: 0.2089 - accuracy: 0.9870
# Epoch 25/100
# 155/155 [==============================] - 1s 4ms/step - loss: 0.2072 - accuracy: 0.9852
# Epoch 26/100
# 155/155 [==============================] - 1s 5ms/step - loss: 0.2063 - accuracy: 0.9926
# Epoch 27/100
# 155/155 [==============================] - 1s 5ms/step - loss: 0.2069 - accuracy: 0.9926
# Epoch 28/100
# 155/155 [==============================] - 1s 4ms/step - loss: 0.2083 - accuracy: 0.9907
# Epoch 29/100
# 155/155 [==============================] - 1s 4ms/step - loss: 0.2055 - accuracy: 0.9880
# Epoch 30/100
# 155/155 [==============================] - 1s 5ms/step - loss: 0.2072 - accuracy: 0.9880
# Epoch 31/100
# 155/155 [==============================] - 1s 5ms/step - loss: 0.2083 - accuracy: 0.9889
# Epoch 32/100
# 155/155 [==============================] - 1s 5ms/step - loss: 0.2065 - accuracy: 0.9907
# Epoch 33/100
# 155/155 [==============================] - 1s 5ms/step - loss: 0.2066 - accuracy: 0.9889
# Epoch 34/100
# 155/155 [==============================] - 1s 4ms/step - loss: 0.2067 - accuracy: 0.9907
# Epoch 35/100
# 155/155 [==============================] - 1s 5ms/step - loss: 0.2054 - accuracy: 0.9917
# Epoch 36/100
# 155/155 [==============================] - 1s 4ms/step - loss: 0.2075 - accuracy: 0.9889
# Epoch 37/100
# 155/155 [==============================] - 1s 5ms/step - loss: 0.2064 - accuracy: 0.9917
# Epoch 38/100
# 155/155 [==============================] - 1s 4ms/step - loss: 0.2070 - accuracy: 0.9898
# Epoch 39/100
# 155/155 [==============================] - 1s 4ms/step - loss: 0.2095 - accuracy: 0.9861
# Epoch 40/100
# 155/155 [==============================] - 1s 5ms/step - loss: 0.2074 - accuracy: 0.9898
# Epoch 41/100
# 155/155 [==============================] - 1s 4ms/step - loss: 0.2060 - accuracy: 0.9917
# Epoch 42/100
# 155/155 [==============================] - 1s 5ms/step - loss: 0.2065 - accuracy: 0.9944
# Epoch 43/100
# 155/155 [==============================] - 1s 5ms/step - loss: 0.2062 - accuracy: 0.9917
# Epoch 44/100
# 155/155 [==============================] - 1s 5ms/step - loss: 0.2069 - accuracy: 0.9889
# Epoch 45/100
# 155/155 [==============================] - 1s 5ms/step - loss: 0.2084 - accuracy: 0.9880
# Epoch 46/100
# 155/155 [==============================] - 1s 5ms/step - loss: 0.2046 - accuracy: 0.9935
# Epoch 47/100
# 155/155 [==============================] - 1s 5ms/step - loss: 0.2067 - accuracy: 0.9907
# Epoch 48/100
# 155/155 [==============================] - 1s 5ms/step - loss: 0.2063 - accuracy: 0.9926
# Epoch 49/100
# 155/155 [==============================] - 1s 5ms/step - loss: 0.2068 - accuracy: 0.9880
# Epoch 50/100
# 155/155 [==============================] - 1s 5ms/step - loss: 0.2083 - accuracy: 0.9907
# Epoch 51/100
# 155/155 [==============================] - 1s 5ms/step - loss: 0.2054 - accuracy: 0.9880
# Epoch 52/100
# 155/155 [==============================] - 1s 5ms/step - loss: 0.2047 - accuracy: 0.9917
# Epoch 53/100
# 155/155 [==============================] - 1s 5ms/step - loss: 0.2057 - accuracy: 0.9898
# Epoch 54/100
# 155/155 [==============================] - 1s 5ms/step - loss: 0.2064 - accuracy: 0.9870
# Epoch 55/100
# 155/155 [==============================] - 1s 5ms/step - loss: 0.2063 - accuracy: 0.9889
# Epoch 56/100
# 155/155 [==============================] - 1s 5ms/step - loss: 0.2072 - accuracy: 0.9852
# Epoch 57/100
# 155/155 [==============================] - 1s 5ms/step - loss: 0.2059 - accuracy: 0.9926
# Epoch 58/100
# 155/155 [==============================] - 1s 5ms/step - loss: 0.2058 - accuracy: 0.9907
# Epoch 59/100
# 155/155 [==============================] - 1s 5ms/step - loss: 0.2067 - accuracy: 0.9907
# Epoch 60/100
# 155/155 [==============================] - 1s 5ms/step - loss: 0.2064 - accuracy: 0.9880
# Epoch 61/100
# 155/155 [==============================] - 1s 5ms/step - loss: 0.2057 - accuracy: 0.9917
# Epoch 62/100
# 155/155 [==============================] - 1s 5ms/step - loss: 0.2084 - accuracy: 0.9852
# Epoch 63/100
# 155/155 [==============================] - 1s 5ms/step - loss: 0.2070 - accuracy: 0.9889
# Epoch 64/100
# 155/155 [==============================] - 1s 5ms/step - loss: 0.2051 - accuracy: 0.9944
# Epoch 65/100
# 155/155 [==============================] - 1s 5ms/step - loss: 0.2078 - accuracy: 0.9833
# Epoch 66/100
# 155/155 [==============================] - 1s 5ms/step - loss: 0.2074 - accuracy: 0.9880
# Epoch 67/100
# 155/155 [==============================] - 1s 5ms/step - loss: 0.2049 - accuracy: 0.9889
# Epoch 68/100
# 155/155 [==============================] - 1s 5ms/step - loss: 0.2042 - accuracy: 0.9935
# Epoch 69/100
# 155/155 [==============================] - 1s 5ms/step - loss: 0.2060 - accuracy: 0.9935
# Epoch 70/100
# 155/155 [==============================] - 1s 5ms/step - loss: 0.2059 - accuracy: 0.9898
# Epoch 71/100
# 155/155 [==============================] - 1s 5ms/step - loss: 0.2075 - accuracy: 0.9889
# Epoch 72/100
# 155/155 [==============================] - 1s 5ms/step - loss: 0.2061 - accuracy: 0.9917
# Epoch 73/100
# 155/155 [==============================] - 1s 5ms/step - loss: 0.2065 - accuracy: 0.9907
# Epoch 74/100
# 155/155 [==============================] - 1s 5ms/step - loss: 0.2042 - accuracy: 0.9926
# Epoch 75/100
# 155/155 [==============================] - 1s 5ms/step - loss: 0.2053 - accuracy: 0.9907
# Epoch 76/100
# 155/155 [==============================] - 1s 5ms/step - loss: 0.2042 - accuracy: 0.9898
# Epoch 77/100
# 155/155 [==============================] - 1s 5ms/step - loss: 0.2056 - accuracy: 0.9880
# Epoch 78/100
# 155/155 [==============================] - 1s 5ms/step - loss: 0.2051 - accuracy: 0.9954
# Epoch 79/100
# 155/155 [==============================] - 1s 5ms/step - loss: 0.2049 - accuracy: 0.9917
# Epoch 80/100
# 155/155 [==============================] - 1s 5ms/step - loss: 0.2044 - accuracy: 0.9917
# Epoch 81/100
# 155/155 [==============================] - 1s 5ms/step - loss: 0.2052 - accuracy: 0.9917
# Epoch 82/100
# 155/155 [==============================] - 1s 5ms/step - loss: 0.2038 - accuracy: 0.9935
# Epoch 83/100
# 155/155 [==============================] - 1s 5ms/step - loss: 0.2045 - accuracy: 0.9907
# Epoch 84/100
# 155/155 [==============================] - 1s 5ms/step - loss: 0.2052 - accuracy: 0.9926
# Epoch 85/100
# 155/155 [==============================] - 1s 5ms/step - loss: 0.2049 - accuracy: 0.9907
# Epoch 86/100
# 155/155 [==============================] - 1s 5ms/step - loss: 0.2041 - accuracy: 0.9926
# Epoch 87/100
# 155/155 [==============================] - 1s 5ms/step - loss: 0.2043 - accuracy: 0.9935
# Epoch 88/100
# 155/155 [==============================] - 1s 5ms/step - loss: 0.2059 - accuracy: 0.9898
# Epoch 89/100
# 155/155 [==============================] - 1s 5ms/step - loss: 0.2066 - accuracy: 0.9917
# Epoch 90/100
# 155/155 [==============================] - 1s 5ms/step - loss: 0.2036 - accuracy: 0.9917
# Epoch 91/100
# 155/155 [==============================] - 1s 6ms/step - loss: 0.2029 - accuracy: 0.9935
# Epoch 92/100
# 155/155 [==============================] - 1s 5ms/step - loss: 0.2037 - accuracy: 0.9880
# Epoch 93/100
# 155/155 [==============================] - 1s 5ms/step - loss: 0.2052 - accuracy: 0.9917
# Epoch 94/100
# 155/155 [==============================] - 1s 5ms/step - loss: 0.2048 - accuracy: 0.9917
# Epoch 95/100
# 155/155 [==============================] - 1s 5ms/step - loss: 0.2042 - accuracy: 0.9954
# Epoch 96/100
# 155/155 [==============================] - 1s 5ms/step - loss: 0.2045 - accuracy: 0.9935
# Epoch 97/100
# 155/155 [==============================] - 1s 5ms/step - loss: 0.2054 - accuracy: 0.9889
# Epoch 98/100
# 155/155 [==============================] - 1s 5ms/step - loss: 0.2045 - accuracy: 0.9880
# Epoch 99/100
# 155/155 [==============================] - 1s 5ms/step - loss: 0.2051 - accuracy: 0.9926
# Epoch 100/100
# 155/155 [==============================] - 1s 5ms/step - loss: 0.2048 - accuracy: 0.9917

# %% [markdown]
# **If the training works, congratulations! You have built a model for recognizing SIGN language.**

# %%
model.evaluate(X_test,Y_test)
# Out:
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2823 - accuracy: 0.8667
# [0.28231993317604065, 0.8666666746139526]

# %% [markdown]
# # 5. Grading rule
#
# ***Try your best to achieve high accuarcy.  The grade for this homework will based on your model final training accurracy and test accuracy. ***
#
# For example, if your final training accurracy is 87.8 (consider one decimal) and test accuracy is 70.9, the total grade is 8.78 + 7.09 =15.87. The full credit is 10+10 =20.  It is hard to get full credit in this homework, please try your best.

# %% [markdown]
# **Tips**
#
# You can try to improve its accuracy by:
# 1. tuning the hyperparameters (learning rate, batch size, epoches and so on)
# 2. adjusting your layers numbers or nuron numbers.
# 3. changing optimizer or loss function
# 4. using dropout layer
# 5. add regularizers.L2
# 6. .....

# %% [markdown]
# Once again, here's a thumbs up for your work!

# %%
# %pylab inline
import matplotlib.image as mpimg
img = mpimg.imread('images/thumbs_up.jpg')
imgplot = plt.imshow(img)
plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib
